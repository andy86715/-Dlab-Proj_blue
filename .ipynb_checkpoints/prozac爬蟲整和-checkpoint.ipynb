# %%
import requests
from bs4 import BeautifulSoup

a = 1661
b = 1665

def get_title():
    for i in range(a,b):
        res = requests.get("https://www.ptt.cc/bbs/prozac/index"+str(i)+".html")
        soup = BeautifulSoup(res.text)
        for website in soup.select(".r-ent"):
            try:    
                res2 = requests.get('https://www.ptt.cc/'+website("a")[0]['href'])
                soup2 = BeautifulSoup(res2.text)
                if "資訊" in (soup2.select(".article-meta-value")[2].text):
                    pass
                else:
                    print(soup2.select(".article-meta-tag")[2].text,":",soup2.select(".article-meta-value")[2].text)
            except:
                pass

def get_author():
    for i in range(a,b):
        res = requests.get("https://www.ptt.cc/bbs/prozac/index"+str(i)+".html")
        soup = BeautifulSoup(res.text)
        for website in soup.select(".r-ent"):
            try:    
                res2 = requests.get('https://www.ptt.cc/'+website("a")[0]['href'])
                soup2 = BeautifulSoup(res2.text)
                if "資訊" in (soup2.select(".article-meta-value")[2].text):
                    pass
                else:
                    print(soup2.select(".article-meta-tag")[0].text,":",soup2.select(".article-meta-value")[0].text)
            except:
                pass

def get_time():
    for i in range(a,b):
        res = requests.get("https://www.ptt.cc/bbs/prozac/index"+str(i)+".html")
        soup = BeautifulSoup(res.text)
        for website in soup.select(".r-ent"):
            try:    
                res2 = requests.get('https://www.ptt.cc/'+website("a")[0]['href'])
                soup2 = BeautifulSoup(res2.text)
                if "資訊" in (soup2.select(".article-meta-value")[2].text):
                    pass
                else:
                    print(soup2.select(".article-meta-tag")[3].text,":",soup2.select(".article-meta-value")[3].text)
            except:
                pass

def get_content():
    for i in range(a,b):
        res = requests.get("https://www.ptt.cc/bbs/prozac/index"+str(i)+".html")
        soup = BeautifulSoup(res.text)
        for website in soup.select(".r-ent"):
            try:
                res2 = requests.get('https://www.ptt.cc/'+website("a")[0]['href'])
                soup2 = BeautifulSoup(res2.text)
                if "資訊" in (soup2.select(".article-meta-value")[2].text):
                    pass
                else:
                    print("--------------------------------------------------------------------------------------------------")
                    soup3 = soup2.select(".bbs-screen.bbs-content")[0].text
                    content =soup3.split("※") and soup3.split("--")
                    content2 = content[0].split("2016")
                    print(content2[1])
            except:
                pass

def get_reply():
    for i in range(a,b):
        res = requests.get("https://www.ptt.cc/bbs/prozac/index"+str(i)+".html")
        soup = BeautifulSoup(res.text)
        for website in soup.select(".r-ent"):
            try:    
                res2 = requests.get('https://www.ptt.cc/'+website("a")[0]['href'])
                soup2 = BeautifulSoup(res2.text)
                if "資訊" in (soup2.select(".article-meta-value")[2].text):
                    pass
                else:
                    print("--------------------------------------------------------------------------------------------------")
                    for i in range(len(soup2.select(".push"))):
                        print(soup2.select(".push-tag")[i].text,soup2.select(".push-userid")[i].text,":",soup2.select(".push-content")[i].text)
            except:
                pass

# print(get_title())
print(get_author())
# print(get_time())
# print(get_content())
# print(get_reply())
# Out:
# C:\Users\弘林\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file C:\Users\弘林\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# 作者 : ej01019 (真正)
# 作者 : blackclown (唇)
# 作者 : babe18 (love國光E姊蘇心甯)
# 作者 : DavidJam (平安又有錢才是福)
# 作者 : happy00 (輕快步伐)
# 作者 : blueskymaple (大谷翔平我老公)
# 作者 : wearesad5566 (我難過)
# 作者 : nagnukiy (冠)
# 作者 : eternalfall (不能飛所以墜落)
# 作者 : sanelle (sanelle)
# 作者 : burgergirl (20 seconds insane)
# 作者 : Yinsin (少女心大叔)
# 作者 : ghost1125 (手肘脫臼)
# 作者 : wanchieh (披著狼皮的羊)
# 作者 : FlyFuta (想做啥就做啥的腐太)
# 作者 : hesione (我離開我自己)
# 作者 : tsukiji (大司壽)
# 作者 : RIPsomeday (蘇十月)
# 作者 : horng31208 (horng31208)
# 作者 : qqqlisa (兔子蹦蹦跳跳)
# 作者 : eternalfall (不能飛所以墜落)
# 作者 : waleyu (芋頭)
# 作者 : ej01019 (真正)
# 作者 : jengeddie (calling)
# 作者 : UntermRad (黃色檸檬樹)
# 作者 : thinkKing (想想)
# 作者 : socola (你好嗎?)
# 作者 : flying1618 (六年)
# 作者 : babe18 (love國光E姊蘇心甯)
# 作者 : lyviasun (:))
# 作者 : ej01019 (真正)
# 作者 : hunter10 (觀察自己)
# 作者 : UntermRad (黃色檸檬樹)
# 作者 : seaopal (opalsea)
# 作者 : glenrice (爆日踢韓勦共匪 )
# 作者 : hesione (我離開我自己)
# 作者 : knai (月)
# 作者 : rem20020426 (  囉囉 A-Lo　)
# 作者 : k09090806 (JY)
# 作者 : newbears (小孩先生)
# 作者 : DavidJam (平安又有錢才是福)
# 作者 : flying1618 (六年)
# 作者 : bartwang (利禦寇)
# 作者 : ej01019 (真正)
# 作者 : LouiseaX ()
# 作者 : nagnukiy (冠)
# 作者 : feynmanx (Westworld Arnold)
# 作者 : ilegenes (ilegenes)
# 作者 : sheepinair (綿羊在空中)
# 作者 : kid3875215 (銘哥)
# 作者 : DavidJam (平安又有錢才是福)
# 作者 : hunter10 (觀察自己)
# 作者 : happyliz (試過才知道)
# 作者 : FlyFuta (想做啥就做啥的腐太)
# 作者 : burgergirl (20 seconds insane)
# 作者 : sw810317 (HuaiSw)
# 作者 : hsuyungte (恰恰老大)
# 作者 : rosalic0423 (流緒)
# 作者 : DavidJam (平安又有錢才是福)
# 作者 : eternalfall (不能飛所以墜落)
# 作者 : jayyen7 (小傑)
# 作者 : lydiahsieh (Lydia)
# 作者 : yukilala (水藍色)
# 作者 : DavidJam (平安又有錢才是福)
# 作者 : dont2mind (想破腦袋)
# 作者 : imyuya (夜灰)
# 作者 : UntermRad (黃色檸檬樹)
# 作者 : mayday0609 (Rock!!!)
# 作者 : burgergirl (20 seconds insane)
# 作者 : RIPsomeday (蘇十月)
# 作者 : jack12872 (炎煉凡爾斯)
# 作者 : Belieeve (芥末拿鐵)
# 作者 : joycelove (瑤兒。　　遙望某個人兒~)
# 作者 : belt (可可-smokin' cigarette)
# 作者 : llocation (早春˙蟲鳴˙回暖)
# 作者 : joycelove (瑤兒。　　遙望某個人兒~)
# 作者 : Shelin (夜空)
# None
