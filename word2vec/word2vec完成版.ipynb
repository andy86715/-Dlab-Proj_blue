# %%
import xlrd
from nltk.corpus import stopwords
stop=stopwords.words(r"stop_words2.txt")

data = xlrd.open_workbook('blue.xlsx')
table = data.sheets()[0]
nrows = table.nrows
a=[]
for i in range(nrows):
    a.append(table.row_values(i)[5])

e=[]
for f in a:
    if f==0:
        pass
    else:
        f=f.replace('\n','')
        f=f.replace(' ','')
        g=(f.split('/'))
        g = list(filter(None, g))
        if not g:
            print(g)
        else:
            e.append(g)
kk=[]
tn=0
for sen in e[1:]:
    print(tn)
#     tn+=1
    for word in sen: 
        tn=tn+1
    filtered_words = [word for word in sen if word not in stop]
    kk.append(filtered_words)
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ...

# %%
import xlrd
data = xlrd.open_workbook('憂鬱關鍵字.xlsx')
table = data.sheets()[0]
nrows = table.nrows
c=[]
for i in range(nrows):
    c.append(table.row_values(i)[3])
d=[]
for cc in c:
    b=cc.split('、')
    for bb in b:
        d.append(bb)
for dd in d:
    print(dd)
# Out:
# 關鍵詞彙
# 心情不好
# 開心不起來
# 很受傷
# 寂寞
# 孤單
# 心碎
# 擔心
# 難過
# 低潮
# 無助
# 心是空的
# 傷心
# 心冷
# 心痛
# 空虛
# 落寞
# 失落
# 痛苦
# 淚
# 泣
# 哭
# 玻璃心
# 莫名落淚
# 忍不住哭
# 好不起來
# 撐不下去
# 放棄一切
# 非常不好
# 無法在社會上生存
# 擊垮
# 沒有興趣
# 沒有熱情
# 每天活的像死人
# 什麼事都不想做
# 一直睡
# 失眠
# 難眠
# 睡不著
# 希望能睡得著
# 無法入睡
# 崩潰
# 暴躁
# 慌張
# 焦慮
# 很煩
# 很累
# 無可奈何
# 無力
# 無力感
# 錯愕
# 無能為力
# 疲倦
# 廢物
# 廢人
# 垃圾
# 受夠了
# 我不重要
# 人生完蛋了
# 討厭自己
# 我沒用
# 不正常
# 可悲
# 很糟糕
# 接受不了這樣的自己
# 不被需要的
# 沒有歸屬感
# 情緒和想法無法進入他人心裡
# 孤獨無助
# 世界上沒有人愛我
# 空無一人
# 無人
# 疏遠
# 孤立
# 不被愛
#
# 沒辦法專心
# 腦袋昏沉沉
# 離開
# 好好休息
# 跳下去
# 想消失
# 不想面對
# 躲起來
# 壓抑自己
# 遺憾
# 回到
#
# 沒有方向
# 失去自己
# 胡思亂想
# 茫然
# 失措
# 迷茫
# 走不出來
#
# 藥物
# 諮商

# %%
import xlrd
import nltk
from nltk.corpus import stopwords
# nltk.download()
stop=stopwords.words(r"stop_words2.txt")

data = xlrd.open_workbook('blue.xlsx')
table = data.sheets()[0]
nrows = table.nrows
a=[]
for i in range(nrows):
    a.append(table.row_values(i)[4])
# print(a[8125])
import jieba

    # jieba custom setting.
jieba.set_dictionary('dict.txt.big')

    # load stopwords set
stopwordset = set()
with open(r"stop_words2.txt",'r',encoding='utf-8') as sw:
    for line in sw:
        stopwordset.add(line.strip('\n'))

output = open('wiki_seg.txt','w',encoding='UTF-8')

        
texts_num = 0
    
for aa in a:
    
    if type(aa)==float:
        pass
    else:
        words = jieba.cut(aa, cut_all=False)
        for word in words:
            if word not in stopwordset:

                output.write(word +' ')
        texts_num += 1
#     print(texts_num)    
output.close()
# Out:
# Building prefix dict from C:\Users\Andy.Andy-NB\Documents\python\proj-prozac專案\word2vec\dict.txt.big ...
# Dumping model to file cache C:\Users\ANDY~1.AND\AppData\Local\Temp\jieba.ue18562301c6319cff0e1105f494bdf80.cache
# Loading model cost 2.961 seconds.
# Prefix dict has been built succesfully.

# %%
#製作模型，訓練data
from gensim.models import word2vec
import logging

def main():

    logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
    sentences = word2vec.Text8Corpus("wiki_seg.txt")
    model = word2vec.Word2Vec(sentences, size=250)

    #保存模型，供日後使用
    model.save("med250.model.bin")

    #模型讀取方式
    # model = word2vec.Word2Vec.load("your_model.bin")

if __name__ == "__main__":
    main()
# Out:
# C:\Users\Andy.Andy-NB\Anaconda3\lib\site-packages\gensim\utils.py:855: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Slow version of gensim.models.doc2vec is being used
# 2017-04-03 18:23:50,778 : WARNING : Slow version of gensim.models.word2vec is being used
# 2017-04-03 18:23:50,779 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2017-04-03 18:23:50,780 : INFO : collecting all words and their counts
# 2017-04-03 18:23:50,837 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-04-03 18:23:52,255 : INFO : collected 99466 word types from a corpus of 1390736 raw words and 140 sentences
# 2017-04-03 18:23:52,256 : INFO : Loading a fresh vocabulary
# 2017-04-03 18:23:52,654 : INFO : min_count=5 retains 23897 unique words (24% of original 99466, drops 75569)
# ...

# %%
#結果呈現
from gensim.models import word2vec
from gensim import models
import logging

def main():
	logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
	model = models.Word2Vec.load('med250.model.bin')

	print("提供 3 種測試模式\n")
	print("輸入一個詞，則去尋找前10個該詞的相似詞")
	print("輸入兩個詞，則去計算兩個詞的餘弦相似度")
	print("輸入三個詞，進行類比推理")

	while True:
		try:
			query = input()
			q_list = query.split()

			if len(q_list) == 1:
				print("相似詞前 10 排序")
				res = model.most_similar(q_list[0],topn = 10)
				for item in res:
					print(item[0]+","+str(item[1]))

			elif len(q_list) == 2:
				print("計算 Cosine 相似度")
				res = model.similarity(q_list[0],q_list[1])
				print(res)
			else:
				print("%s之於%s，如%s之於" % (q_list[0],q_list[2],q_list[1]))
				res = model.most_similar([q_list[0],q_list[1]], [q_list[2]], topn= 100)
				for item in res:
					print(item[0]+","+str(item[1]))
			print("----------------------------")
		except Exception as e:
			print(repr(e))

if __name__ == "__main__":
	main()
# Out:
# C:\Users\Andy.Andy-NB\Anaconda3\lib\site-packages\gensim\utils.py:855: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Slow version of gensim.models.doc2vec is being used
# 2017-04-04 12:24:45,682 : INFO : loading Word2Vec object from med250.model.bin
# 2017-04-04 12:24:46,906 : INFO : loading wv recursively from med250.model.bin.wv.* with mmap=None
# 2017-04-04 12:24:46,908 : INFO : setting ignored attribute syn0norm to None
# 2017-04-04 12:24:46,910 : INFO : setting ignored attribute cum_table to None
# 2017-04-04 12:24:46,912 : INFO : loaded med250.model.bin
# 提供 3 種測試模式
#
# 輸入一個詞，則去尋找前10個該詞的相似詞
# 輸入兩個詞，則去計算兩個詞的餘弦相似度
# 輸入三個詞，進行類比推理
# 開心不起來
# 2017-04-04 12:24:59,331 : INFO : precomputing L2-norms of word weight vectors
# 相似詞前 10 排序
# 靜下來,0.9620282649993896
# 忘掉,0.9539119005203247
# 吞沒,0.9528000354766846
# 笑過,0.9526498913764954
# 極點,0.9517180919647217
# 糾結,0.9499859809875488
# ...
