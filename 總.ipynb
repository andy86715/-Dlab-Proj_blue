# %%
import requests
from bs4 import BeautifulSoup
import jieba
a = 1661
b = 1665

jieba.set_dictionary('dict.txt.big')

def get_title():
    for i in range(a,b):
        res = requests.get("https://www.ptt.cc/bbs/prozac/index"+str(i)+".html")
        soup = BeautifulSoup(res.text)
        for website in soup.select(".r-ent"):
            try:    
                res2 = requests.get('https://www.ptt.cc/'+website("a")[0]['href'])
                soup2 = BeautifulSoup(res2.text)
                if "資訊" in (soup2.select(".article-meta-value")[2].text):
                    pass
                else:
                    print(soup2.select(".article-meta-tag")[2].text,":",soup2.select(".article-meta-value")[2].text)
            except:
                pass

def get_author():
    for i in range(a,b):
        res = requests.get("https://www.ptt.cc/bbs/prozac/index"+str(i)+".html")
        soup = BeautifulSoup(res.text)
        for website in soup.select(".r-ent"):
            try:    
                res2 = requests.get('https://www.ptt.cc/'+website("a")[0]['href'])
                soup2 = BeautifulSoup(res2.text)
                if "資訊" in (soup2.select(".article-meta-value")[2].text):
                    pass
                else:
                    print(soup2.select(".article-meta-tag")[0].text,":",soup2.select(".article-meta-value")[0].text)
            except:
                pass

def get_time():
    for i in range(a,b):
        res = requests.get("https://www.ptt.cc/bbs/prozac/index"+str(i)+".html")
        soup = BeautifulSoup(res.text)
        for website in soup.select(".r-ent"):
            try:    
                res2 = requests.get('https://www.ptt.cc/'+website("a")[0]['href'])
                soup2 = BeautifulSoup(res2.text)
                if "資訊" in (soup2.select(".article-meta-value")[2].text):
                    pass
                else:
                    print(soup2.select(".article-meta-tag")[3].text,":",soup2.select(".article-meta-value")[3].text)
            except:
                pass

def get_content():
    for i in range(a,b):
        res = requests.get("https://www.ptt.cc/bbs/prozac/index"+str(i)+".html")
        soup = BeautifulSoup(res.text)
        for website in soup.select(".r-ent"):
            try:
                res2 = requests.get('https://www.ptt.cc/'+website("a")[0]['href'])
                soup2 = BeautifulSoup(res2.text)
                if "資訊" in (soup2.select(".article-meta-value")[2].text):
                    pass
                else:
                    print("--------------------------------------------------------------------------------------------------")
                    soup3 = soup2.select(".bbs-screen.bbs-content")[0].text
                    content =soup3.split("※") and soup3.split("--")
                    content2 = content[0].split("2016")
                    print(content2[1])
            except:
                pass

def get_reply():
    for i in range(a,b):
        res = requests.get("https://www.ptt.cc/bbs/prozac/index"+str(i)+".html")
        soup = BeautifulSoup(res.text)
        for website in soup.select(".r-ent"):
            try:    
                res2 = requests.get('https://www.ptt.cc/'+website("a")[0]['href'])
                soup2 = BeautifulSoup(res2.text)
                if "資訊" in (soup2.select(".article-meta-value")[2].text):
                    pass
                else:
                    print("--------------------------------------------------------------------------------------------------")
                    for i in range(len(soup2.select(".push"))):
                        print(soup2.select(".push-tag")[i].text,soup2.select(".push-userid")[i].text,":",soup2.select(".push-content")[i].text)
            except:
                pass

# print(get_title())
# print(get_author())
# print(get_time())
print(get_content())
# print(get_reply())
