# %%
from __future__ import print_function
import pymysql.cursors
import xlsxwriter

# %%
db = pymysql.connect(host="localhost", user="root", password="", db="proj_blue_server",charset='utf8mb4',port = 3306)
cursor = db.cursor()

# %%
# cursor.execute("SELECT notes1_1,notes1_2,notes1_3,notes2_1,notes3_1,notes4_1,notes5_1,notes6_1,notes6_2,notes7_1,notes8_1,notes9_1,notes9_2,notes9_3,notes9_4 FROM emotion")

# for row in cursor:
#     for row2 in row:
#         if row2 =="":
#             pass
#         else:
#             print(row2)

# %%
workbook = xlsxwriter.Workbook('prozac_newword2.xlsx')#create a file 
worksheet = workbook.add_worksheet()#create a sheet

e1 = []
e2 = []
e3 = []
e4 = []
e5 = []
e6 = []
e7 = []
e8 = []
e9 = []
e10 = []
e11 = []
e12 = []
e13 = []
e14 = []
e15 = []
e16 = []
e17 = []

cursor.execute("SELECT notes1_1 FROM emotion")
# print("負向情緒:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e1.append(row2)

cursor.execute("SELECT notes1_2 FROM emotion")
# print("無緣無故哭泣:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e2.append(row2)

cursor.execute("SELECT notes1_3 FROM emotion")
# print("感到痛苦、絕望:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e3.append(row2)

cursor.execute("SELECT notes2_1 FROM emotion")
# print("失去活力、興趣、愉悅感:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e4.append(row2)

cursor.execute("SELECT notes3_1 FROM emotion")
# print("睡眠不正常:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e5.append(row2)

cursor.execute("SELECT notes4_1 FROM emotion")
# print("情緒不穩、暴躁、易怒:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e6.append(row2)           

cursor.execute("SELECT notes5_1 FROM emotion")
# print("感覺倦怠:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e7.append(row2)

cursor.execute("SELECT notes6_1 FROM emotion")
# print("自我否定:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e8.append(row2)

cursor.execute("SELECT notes6_2 FROM emotion")
# print("人際問題:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e9.append(row2)

cursor.execute("SELECT notes7_1 FROM emotion")
# print("無法集中精神:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e10.append(row2)

cursor.execute("SELECT notes8_1 FROM emotion")
# print("有死亡想法、自殺意念及計畫:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e11.append(row2)

cursor.execute("SELECT notes9_1 FROM emotion")
# print("消極想法:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e12.append(row2)

cursor.execute("SELECT notes9_2 FROM emotion")
# print("遺憾為中心的憂鬱:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e13.append(row2)

cursor.execute("SELECT notes9_3 FROM emotion")
# print("缺乏動機、感到迷茫:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e14.append(row2)

cursor.execute("SELECT notes9_4 FROM emotion")
# print("具憂鬱病識感:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e15.append(row2)
            
cursor.execute("SELECT notes10_1 FROM emotion")
# print("生理症狀:")
for row in cursor:
    for row2 in row:
        if row2 == "":
            pass
        elif row2 == None:
            pass
        else:
            e16.append(row2)
            
cursor.execute("SELECT notes11_1 FROM emotion")
# print("求救訊號:")
for row in cursor:
    for row2 in row:
        if row2 == "":
            pass
        elif row2 == None:
            pass
        else:
            e17.append(row2)

cursor.execute("SELECT notes1_1 FROM emotion_2")
# print("負向情緒:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e1.append(row2)
# print(e1)

cursor.execute("SELECT notes1_2 FROM emotion_2")
# print("無緣無故哭泣:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e2.append(row2)
# print(e2)

cursor.execute("SELECT notes1_3 FROM emotion_2")
# print("感到痛苦、絕望:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e3.append(row2)
# print(e3)

cursor.execute("SELECT notes2_1 FROM emotion_2")
# print("失去活力、興趣、愉悅感:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e4.append(row2)
# print(e4)

cursor.execute("SELECT notes3_1 FROM emotion_2")
# print("睡眠不正常:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e5.append(row2)
# print(e5)

cursor.execute("SELECT notes4_1 FROM emotion_2")
# print("情緒不穩、暴躁、易怒:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e6.append(row2)
# print(e6)            

cursor.execute("SELECT notes5_1 FROM emotion_2")
# print("感覺倦怠:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e7.append(row2)
# print(e7)

cursor.execute("SELECT notes6_1 FROM emotion_2")
# print("自我否定:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e8.append(row2)
# print(e8)

cursor.execute("SELECT notes6_2 FROM emotion_2")
# print("人際問題:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e9.append(row2)
# print(e9)

cursor.execute("SELECT notes7_1 FROM emotion_2")
# print("無法集中精神:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e10.append(row2)
# print(e10)

cursor.execute("SELECT notes8_1 FROM emotion_2")
# print("有死亡想法、自殺意念及計畫:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e11.append(row2)
# print(e11)

cursor.execute("SELECT notes9_1 FROM emotion_2")
# print("消極想法:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e12.append(row2)
# print(e12)

cursor.execute("SELECT notes9_2 FROM emotion_2")
# print("遺憾為中心的憂鬱:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e13.append(row2)
# print(e13)

cursor.execute("SELECT notes9_3 FROM emotion_2")
# print("缺乏動機、感到迷茫:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e14.append(row2)
# print(e14)

cursor.execute("SELECT notes9_4 FROM emotion_2")
# print("具憂鬱病識感:")
for row in cursor:
    for row2 in row:
        if row2 =="":
            pass
        else:
            e15.append(row2)
# print(e15)

cursor.execute("SELECT notes10_1 FROM emotion_2")
# print("具憂鬱病識感:")
for row in cursor:
    for row2 in row:
        if row2 == "":
            pass
        elif row2 == None:
            pass
        else:
            e16.append(row2)
            
cursor.execute("SELECT notes11_1 FROM emotion_2")
# print("具憂鬱病識感:")
for row in cursor:
    for row2 in row:
        if row2 == "":
            pass
        elif row2 == None:
            pass
        else:
            e17.append(row2)

row=1
worksheet.write(0, 0,"負向情緒")
for each_cagetory in e1:
    worksheet.write(row, 0,each_cagetory)
    row = row+1
    
row=1
worksheet.write(0, 1,"無緣無故哭泣 ")
for each_cagetory in e2:
    worksheet.write(row, 1,each_cagetory)
    row = row+1

row=1
worksheet.write(0, 2,"感到痛苦、絕望  ")
for each_cagetory in e3:
    worksheet.write(row, 2,each_cagetory)
    row = row+1

row=1
worksheet.write(0, 3,"失去活力、興趣、愉悅感  ")
for each_cagetory in e4:
    worksheet.write(row, 3,each_cagetory)
    row = row+1
    
row=1
worksheet.write(0, 4,"睡眠不正常  ")
for each_cagetory in e5:
    worksheet.write(row, 4,each_cagetory)
    row = row+1
    
row=1
worksheet.write(0, 5,"情緒不穩、暴躁、易怒")
for each_cagetory in e6:
    worksheet.write(row, 5,each_cagetory)
    row = row+1
    
row=1
worksheet.write(0, 6,"感覺倦怠 ")
for each_cagetory in e7:
    worksheet.write(row, 6,each_cagetory)
    row = row+1
    
row=1
worksheet.write(0, 7,"自我否定 ")
for each_cagetory in e8:
    worksheet.write(row, 7,each_cagetory)
    row = row+1
    
row=1
worksheet.write(0, 8,"人際問題 ")
for each_cagetory in e9:
    worksheet.write(row, 8,each_cagetory)
    row = row+1
    
row=1
worksheet.write(0, 9,"無法集中精神 ")
for each_cagetory in e10:
    worksheet.write(row, 9,each_cagetory)
    row = row+1
    
row=1
worksheet.write(0, 10,"有死亡想法、自殺意念及計畫")
for each_cagetory in e11:
    worksheet.write(row, 10,each_cagetory)
    row = row+1
    
row=1
worksheet.write(0, 11,"消極想法 ")
for each_cagetory in e12:
    worksheet.write(row, 11,each_cagetory)
    row = row+1
    
row=1
worksheet.write(0, 12,"遺憾為中心的憂鬱 ")
for each_cagetory in e13:
    worksheet.write(row, 12,each_cagetory)
    row = row+1
    
row=1
worksheet.write(0, 13,"缺乏動機、感到迷茫 ")
for each_cagetory in e14:
    worksheet.write(row, 13,each_cagetory)
    row = row+1
    
row=1
worksheet.write(0, 14,"具憂鬱病識感")
for each_cagetory in e15:
    worksheet.write(row, 14,each_cagetory)
    row = row+1
    
row=1
worksheet.write(0, 15,"生理症狀")
for each_cagetory in e16:
    worksheet.write(row, 15,each_cagetory)
    row = row+1
    
row=1
worksheet.write(0, 16,"求救訊號")
for each_cagetory in e17:
    worksheet.write(row, 16,each_cagetory)
    row = row+1

# %%
cursor.close()
db.close()
