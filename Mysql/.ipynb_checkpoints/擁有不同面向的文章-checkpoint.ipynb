# %%
import pymysql.cursors
import xlsxwriter

# %%
db = pymysql.connect(host="localhost", user="root", password="", db="proj_blue_server",charset='utf8mb4',port = 3306)
cursor = db.cursor()

# %%
workbook = xlsxwriter.Workbook('多狀態文章(1234).xlsx')#create a file 
worksheet = workbook.add_worksheet()#create a sheet

cursor.execute("SELECT * FROM emotion")
worksheet.write(0, 0,"感覺倦怠-負向情緒、死、自我否定")
row=1
for a in cursor:
    if a[25] and a[19] and a[29] and a[26] != '':
        worksheet.write(row, 0,a[1])
        row = row+1

cursor.execute("SELECT * FROM emotion")
worksheet.write(0, 1,"失去活力-感覺倦怠")
row=1
for a in cursor:
    if a[22] and a[25] != "":
        worksheet.write(row, 1,a[1])
        row = row+1

cursor.execute("SELECT * FROM emotion") 
worksheet.write(0, 2,"睡眠不正常-生理狀態")
row=1
for a in cursor:
    if a[23] and a[34] != "":
        worksheet.write(row, 2,a[1])
        row = row+1

cursor.execute("SELECT * FROM emotion")
worksheet.write(0, 3,"負向情緒-情緒不穩定、自我否定、感覺倦怠")
row=1
for a in cursor:
    if a[19] and a[24] and a[26] and a[25] != "":
        worksheet.write(row, 3,a[1])
        row = row+1

cursor.execute("SELECT * FROM emotion")
worksheet.write(0, 4,"人際問題-負向情緒")
row=1
for a in cursor:
    if a[19] and a[27] != "":
        worksheet.write(row, 4,a[1])
        row = row+1

cursor.execute("SELECT * FROM emotion")
worksheet.write(0, 5,"消極想法-死、哭、自我否定")
row=1
for a in cursor:
    if a[30] and a[29] and a[20] and a[26] != "":
        worksheet.write(row, 5,a[1])
        row = row+1
        
cursor.execute("SELECT * FROM emotion")
worksheet.write(0, 6,"無法集中精神-失去活力")
row=1
for a in cursor:
    if a[28] and a[22] != "":
        worksheet.write(row, 6,a[1])
        row = row+1
        
cursor.execute("SELECT * FROM emotion")
worksheet.write(0, 7,"具憂鬱病識感-負向情緒、睡眠不正常、生理狀態")
row=1
for a in cursor:
    if a[33] and a[19] and a[23] and a[34] != "":
        worksheet.write(row, 7,a[1])
        row = row+1

cursor.execute("SELECT * FROM emotion")
worksheet.write(0, 8,"自我否定-人際問題")
row=1
for a in cursor:
    if a[26] and a[27] != "":
        worksheet.write(row, 8,a[1])
        row = row+1

# %%
workbook = xlsxwriter.Workbook('多狀態文章(5678).xlsx')#create a file 
worksheet = workbook.add_worksheet()#create a sheet

cursor.execute("SELECT * FROM emotion_2")
worksheet.write(0, 0,"感覺倦怠-負向情緒、死、自我否定")
row=1
for a in cursor:
    if a[25] and a[19] and a[29] and a[26] != '':
        worksheet.write(row, 0,a[1])
        row = row+1

cursor.execute("SELECT * FROM emotion_2")
worksheet.write(0, 1,"失去活力-感覺倦怠")
row=1
for a in cursor:
    if a[22] and a[25] != "":
        worksheet.write(row, 1,a[1])
        row = row+1

cursor.execute("SELECT * FROM emotion_2") 
worksheet.write(0, 2,"睡眠不正常-生理狀態")
row=1
for a in cursor:
    if a[23] and a[34] != "":
        worksheet.write(row, 2,a[1])
        row = row+1

cursor.execute("SELECT * FROM emotion_2")
worksheet.write(0, 3,"負向情緒-情緒不穩定、自我否定、感覺倦怠")
row=1
for a in cursor:
    if a[19] and a[24] and a[26] and a[25] != "":
        worksheet.write(row, 3,a[1])
        row = row+1

cursor.execute("SELECT * FROM emotion_2")
worksheet.write(0, 4,"人際問題-負向情緒")
row=1
for a in cursor:
    if a[19] and a[27] != "":
        worksheet.write(row, 4,a[1])
        row = row+1

cursor.execute("SELECT * FROM emotion_2")
worksheet.write(0, 5,"消極想法-死、哭、自我否定")
row=1
for a in cursor:
    if a[30] and a[29] and a[20] and a[26] != "":
        worksheet.write(row, 5,a[1])
        row = row+1
        
cursor.execute("SELECT * FROM emotion_2")
worksheet.write(0, 6,"無法集中精神-失去活力")
row=1
for a in cursor:
    if a[28] and a[22] != "":
        worksheet.write(row, 6,a[1])
        row = row+1
        
cursor.execute("SELECT * FROM emotion_2")
worksheet.write(0, 7,"具憂鬱病識感-負向情緒、睡眠不正常、生理狀態")
row=1
for a in cursor:
    if a[33] and a[19] and a[23] and a[34] != "":
        worksheet.write(row, 7,a[1])
        row = row+1

cursor.execute("SELECT * FROM emotion_2")
worksheet.write(0, 8,"自我否定-人際問題")
row=1
for a in cursor:
    if a[26] and a[27] != "":
        worksheet.write(row, 8,a[1])
        row = row+1
