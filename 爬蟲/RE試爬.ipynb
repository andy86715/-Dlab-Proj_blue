# %%
import re
import requests
from bs4 import BeautifulSoup
res = requests.get("https://www.ptt.cc/bbs/prozac/index1653.html")
soup = BeautifulSoup(res.text)
pattern = "^\d{2} 2016$"
regexp = re.compile(pattern)

for website in soup.select(".r-ent"):
    res2 = requests.get('https://www.ptt.cc/'+website("a")[0]['href'])
    soup2 = BeautifulSoup(res2.text)
#     print("--------------------------------------------------------------------------------------------------")
    soup3 = soup2.select(".bbs-screen.bbs-content")[0].text
    print(soup3)
#     for content in soup3:
#         result = regexp.search(content)
#         if result:
#             print(content)
# Out:
# C:\Users\弘林\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file C:\Users\弘林\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# 作者Yinsin (少女心大叔)看板prozac標題[閒聊] Sad時間Sat Dec 10 11:26:19 2016
#
# 今天一大早下台中要把房間退租
# 東西整理整理就等房東來
# 現在事情都已經弄好了
# 準備回家
# 這樣我跟這裡的連結就只剩下不知道要不要繼續讀的學校了
# 在這生活也有三年了
# 雖然盡是與前女友的回憶
# 不過還是有點不捨啊…
# 心情有點沈重
# 卻也沒有到陰天的程度
# 就用閒聊吧………
#
# 念舊的個性真麻煩啊（嘆氣
#
# -----
# Sent from JPTT on my Sony E6853.
#
# --
# Raise if you could.
# For that is our curse.
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 111.83.38.176
# ※ 文章網址: https://www.ptt.cc/bbs/prozac/M.1481340393.A.0BA.html
# 推 ezk: 拍拍 12/10 13:40
# 推 RIPsomeday: 念舊的個性真麻煩+1 12/10 15:03
# 推 lukeloo: 念舊的個性真麻煩+1 12/11 08:51
#
# 作者glitter41 (41)看板prozac標題[問題] 台北接近台北車站的醫生時間Sat Dec 10 12:07:19 2016
#
# 覺得自己需要去找醫生拿藥，版上推薦的醫生比較遠，每次掛完號，去不到那裡就逃回家了...
# 有沒有比較接近北車或是雙和、新店的醫生推薦呢？
# 謝謝...
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 114.136.99.53
# ※ 文章網址: https://www.ptt.cc/bbs/prozac/M.1481342842.A.AB1.html
#
# 作者ezk (蒲葵貓)看板prozac標題[陰天] 逃避論文時間Sat Dec 10 13:42:32 2016
#
#
#    一直想休息，
#
#    一直不想碰論文，
#
#    一直逃避，
#
#    休學年限用到最後了，
#
#    卻還想拿學位，不是矛盾？
#
#    怎樣才能認真一點…
#
#    還是要靠自己吧…唉
#
#
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 140.112.25.105
# ※ 文章網址: https://www.ptt.cc/bbs/prozac/M.1481348554.A.167.html
# 推 k09090806: 拍拍e大 12/10 14:05
# → k09090806: 我根本是在逃避人生了 整天昏睡 12/10 14:05
# → k09090806: 我應該就只是軟爛orz 12/10 14:06
# → ezk: 我也曾有幾個月，每天昏睡，不洗澡也不吃飯 12/10 14:09
# → ezk: 最近算是有改善，出門去圖書館，可是一直上網沒在寫論文 12/10 14:10
# 推 eternalfall: e大你陪我走完論文路，你一定也可以的！！ 12/11 00:05
# 推 rosa8545: 加油>< 雖然我是大學部 我也會一直想躺著就好提不起勁 12/11 20:46
# 推 yeh0416: 論文擺爛ing... 12/12 08:24
# 推 nix: 我寫論文時也是生病狀態，那時就是每天睡前和早上起床時禱告 12/12 19:45
# → nix: ，禱告說我今天只要認真的把我今天該寫的進度寫完 (不用訂很 12/12 19:46
# → nix: 高的目標要寫很多，這樣會把自己弄的壓力太大)，其他的事情和 12/12 19:46
# → nix: 未來的事情我不用擔心，剩下的我就交給神。其實我也不算是基 12/12 19:46
# → nix: 督徒，那時只是去過教會幾次，發現禱告的力量很強大。就這樣 12/12 19:46
# → nix: 一步一腳印，通常別人花六個月寫論文，後來我三個月就寫完了 12/12 19:46
# 推 koxinga: 我今年完全忘記交註冊費 大概被研究所退學了吧 12/22 00:47
#
# 作者lydiahsieh (Lydia)看板prozac標題[閒聊] 雷/最近就是這樣時間Sat Dec 10 13:55:29 2016
# 今天回診了，
# 拿到了兩種藥，藥名分別是Sulpiride(50)跟apo-Fluoxetine，想問板上的各位吃了這兩
# 種藥有什麼效用嗎？然後最常出現的副作用是什麼？
#
# -
#
# 最近糟到一個不行，
# 今天特別冷靜下來才可以好好發文，
# 前幾天都崩潰到連發文都嫌麻煩。
#
# 準備要開始寫遺書了，但不知道要寫什麼內容，可能就是對身旁的人的抱歉吧。
# 已經想好兩種一定會死的死法，等到真的受不了的時候就好好照著計畫走吧。
#
# 感覺我就是一個浪費資源的社會敗類呢。
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 114.137.9.145
# ※ 文章網址: https://www.ptt.cc/bbs/prozac/M.1481349331.A.147.html
# 推 RIPsomeday: 我也祝福你 ：） 12/10 18:18
#
# 作者imyuya (夜灰)看板prozac標題[陰天] 於事無補的對不起時間Sat Dec 10 16:57:33 2016
#
#
# 想起阿婆。
#
# 想起過去的那些感情。
#
# 想起很多人。
#
#
#
# 覺得非常非常非常非常非常非常非常非常非常非常非常對不起……
#
# 但對不起根本什麼用都沒有。
#
# 不說有沒有勇氣讓對方聽到，對方聽不聽得到，
#
# 有時聽到反而傷人又一次困擾對方……
#
#
#
# 但還是非常非常非常非常的難過和抱歉……
#
# 為何過去的我這麼渣，這麼糟蹋揮霍別人的好？
#
# 為什麼現在的我還是沒好到哪裡去？
#
#
#
# 也許真的是抱歉，也許只是需要悲傷的理由，
#
# 悲傷愧疚和絕望彷彿無止境的淹上來。
#
# 對不起……
#
# 雖然於事無補還是對不起……
#
#
#
#
#
# 明知道想這些什麼用都沒有，該死的停不下來。
#
# 難過像是永遠停不下來。
#
# 我知道它會停的，但它還會再來。
#
# 這種知道一點都沒有幫助，反而更痛恨自己更難過覺得自己更沒用了……
#
# -----
# Sent from JPTT on my Asus ASUS_T00G.
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 36.236.113.226
# ※ 文章網址: https://www.ptt.cc/bbs/prozac/M.1481360255.A.B1A.html
# → imyuya: 生存於世，我覺得非常抱歉…… 12/10 16:59
# → Shuan222: 乖乖 抱一個 抱很多很多個 12/10 22:11
# 推 colza: 唉，能理解，辛苦了。加油，真的就是加油，活著真的不容易 12/13 07:16
#
# 作者DavidJam (平安又有錢才是福)看板prozac標題[陰天] 討厭唸書時間Sat Dec 10 17:05:23 2016
#
#
#
#         今天又很煩的把資料看完
#
#         看已經看過的資料覺得還好
#
#         蠻順的
#
#
#         看了新的資料
#
#         好煩
#
#         30mins都撐不下去
#
#         草草看完3個標題就放棄了
#
#
#         人真的會充滿無限可能嗎?
#
#         我怎麼覺得自己是沒有可能
#
#
#         很好奇愛唸書的人腦袋到底是怎麼運作的?
#
#         到底一個腦袋差的人
#
#         要怎樣面對自己的生活?人生?
#
#
#         我找不到在這個社會生存的立足點
#
#         每天都很悲觀的活著每一秒
#
#         到底該怎樣才能穩定的過自己的生活
#
#         不用再為生活煩惱?
#
#
#         有些人不用念書
#
#         也不用煩惱自己的生活
#
#         因為家裡有家業可以做
#
#         不需要一個人在外拼搏
#
#         雖然他們錢都很多
#
#         但就是因為太高調
#
#         就被帶去吸毒
#
#
#         我以前很常羨慕他們
#
#         一天工作六到七個小時
#
#         就有錢賺
#
#         每個月一個人的收入大概三萬
#
#         每天還有十個小時左右的自由時間
#
#         雖然他們都把時間花在喝酒跟吸毒裡
#
#         我以前常在想
#
#         如果是我有這些錢和時間
#
#         不知道該有多好
#
#         不用面對陌生的人群
#
#         不用害怕被主管盯
#
#
#         不過這些終究是空想
#
#         因為沒有的東西就是沒有
#
#         不會因為你羨慕
#
#         就會出現
#
#
#         只能說是上一代做的好
#
#         下一代就會被庇蔭
#
#         我的上一代只愛喝酒打牌打麻將上酒店跟酒店妹嘴炮
#
#
#         簡單來說就是靠爸
#
#         而我沒爸可靠
#
#         然後人生前半段都是在被家暴中渡過
#
#         還要幫喝醉酒發酒瘋的上一代按摩 擦嘔吐物 收拾被他摔爛的家具
#
#
#         有人同情我嗎?
#
#         沒有
#
#         沒有人認為我很苦
#
#         甚至很溺愛我爸的奶奶還勸我要一直忍耐
#
#         只為了一句『家醜不可外揚』
#
#
#         『念書有什麼用?回家還不是被打』
#
#         記得在高中的時候我就這麼想
#
#         反正酒鬼喝完酒回家就會打我
#
#         那我唸書要幹嘛?
#
#
#         現在覺得自己老了
#
#         還是要重拾書本
#
#         覺得自己很自卑
#
#
#         只是為了生活
#
#         這是我想不出辦法的辦法
#
#         雖然討厭唸書
#
#         還是不得已的必須唸下去
#
#
#         到底要怎樣日子才能輕鬆的過?
#
#
#         好死不如賴活著
#
#         賴活著真的有比較輕鬆嗎?
#
# --
# 我朋友跟我講一個勵志的故事，他從國中開始半工半讀，
#
# 因為自己的夢想買一棟房子可以靠自己的努力完成，到大
#
# 學一直持續著，終於在最後存到20萬元......加上爸爸贊助的1980萬元，終於住進豪宅。
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 39.8.103.143
# ※ 文章網址: https://www.ptt.cc/bbs/prozac/M.1481360728.A.1E1.html
# 推 RIPsomeday: 不喜歡現在的科系嗎 12/10 17:26
# 推 lyviasun: 我認為你很苦，我同情你。但如果你一直覺得別人過很爽， 12/10 18:10
# → lyviasun: 自己就是倒楣擺脫不了命運。那你會更痛苦脫離不了現況。 12/10 18:10
# → hesione: 推樓上。 12/10 18:14
# → isorange: 最討厭的是很努力念了卻還是比不上別人 12/10 20:01
# 推 bartwang: D大，拍拍，人生真的很苦 12/10 20:39
# 推 qqqlisa: 我喜歡看書  但不喜歡唸書 12/10 21:33
# 推 FlyFuta: 我不喜歡上學，但是好不容易考進去了，為了將來的工作， 12/11 01:44
# → FlyFuta: 這所學校的學歷風評還算不錯，只能一直硬撐 12/11 01:44
# → FlyFuta: 現在在外面補習日文，覺得比起學校，在日文課的我非常認 12/11 01:45
# → FlyFuta: 真的去學，也會找時間複習跟寫作業、找聽力練習 12/11 01:45
# → FlyFuta: 我想我存粹只是想學好日文吧？比起學校的「那些東西」... 12/11 01:46
#
# 作者wearesad5566 (我難過)看板prozac標題[陰天] 還有明天嗎？時間Sat Dec 10 18:09:07 2016
# 前幾天去醫院，媽媽跟醫生談好了要我自己自費住院，因為健保床已經排了三週都沒有消
# 息，只能自己自費，但這對我而言真的是個很大的負擔，我好怕自己繳不出來，而我又在
# 準備明年夏天的考試，一切花費都須由我自己承擔。弟弟聽到了直接跟我說那你就不要裝
# 病啊，我好傷心最愛的弟弟傷我最深，如果可以我也不想生病，被傷害後已經八次住院，
# 六次電療，每次對我都是考驗，都是折磨，如果可以我也不想啊，剛又打電話去問醫生，
# 有沒有其它的路好走，他回答我還是建議住院，我真的真的真的不想再進出醫院了。
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 39.8.97.165
# ※ 文章網址: https://www.ptt.cc/bbs/prozac/M.1481364550.A.2B4.html
# → bbrt: 加油 12/10 19:32
# 推 flower1121: 加油! 12/10 19:51
# 推 RIPsomeday: 會有明天的 只是可能會跟今天一樣糟 或者甚之。 12/10 20:02
# → RIPsomeday: 我就是如此   QQ 12/10 20:02
# 推 bartwang: 拍拍，撐下去就是你的! 12/10 20:37
#
# 作者jk529300 (小花一朵朵)看板prozac標題[陰天] 只是默默覺得很累時間Sat Dec 10 20:11:28 2016
# 最近幾天，
# 深深覺得按照規矩走真的很愚笨，
# 規矩以外，總是有其他道路可以走，
# 傻傻地循規蹈矩，
# 被欺騙、被嘲笑、被說太單純，
# 其他人走捷徑，自己反而繞了遠路。
#
# 可是我就是不想超過太多分際，
# 模糊的關係、多一層的秘密，
# 是很方便，也是籌碼。
#
# 可是我不想把這些拿來輸贏，
#
# 拿著牌算來算去，
# 怎樣能讓自己贏得最多。
#
# 這樣，很累。
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 1.163.71.199
# ※ 文章網址: https://www.ptt.cc/bbs/prozac/M.1481371890.A.32A.html
# 推 qqqlisa: 這標題，我還以為我發文了，唉 12/10 20:22
#
# 作者qqqlisa (兔子蹦蹦跳跳)看板prozac標題[陰天] 快要時間Sat Dec 10 21:15:30 2016
#
# 好像到極限了
# 還好明天開始放假三天
# 但，忍不住遷怒他人
# 我很沒用QQ
#
# 路，是自己選的
# 怨不了他人
#
# 看著櫻桃小丸子的卡通
# 默默想哭
# 如果人與人之間都能這樣單純善良
# 那麼是不是就再也不用上街頭對抗那些邪惡的無知與愚蠢盟盟
#
#
#
# 想逃離的
# 終究是要先面對
#
#
# 有時候覺得人生就像吸毒一樣
# 回不了頭的路
# 過往   不忍回憶
#
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 118.160.27.170
# ※ 文章網址: https://www.ptt.cc/bbs/prozac/M.1481375732.A.936.html
# → qqqlisa: 還是覺得 窩起來 好 12/11 01:34
# 推 RIPsomeday: 想逃＋1 12/11 06:08
#
# 作者lyviasun (:))看板prozac標題[陰天] 花錢時間Sat Dec 10 23:23:57 2016
# 其實今天心情有很多感慨的
#
#
# 但因為我鞋子全濕了，原本也一直想丟掉（因為鞋底都開始脫落了）
#
# 因為腳很大很難買鞋（女鞋最大通常只到25/40，我大概都要穿到26/41）
#
# 所以半年前一口氣花了三千塊買了三雙包鞋
#
# 雖然是挑著百貨公司折扣才買，但以當時窮學生來說一雙鞋一千塊好奢侈
#
# 但腳很大路邊又買不太到...
#
#
# 沒想到半年後有兩雙都快壞了，所以今天全濕之後打定主意那雙不要再穿回家
#
# 一直想著要買雨靴，但因為不知道哪裡有店可以買（不太敢網拍怕尺寸不合）
#
#
# 剛剛就想著要買鞋子穿，最不濟就買一雙超便宜的夾拖換
#
# 看到in the playground的店，
#
# 想說要買雨靴，可是hunter的好厚重，
#
# 想說買雙防水材質的包鞋，但版型太窄
#
#
# 結果最後買了一雙防水材質涼鞋，一千五
#
#
#
#
# 後來想想為什麼我要花一千五買一雙涼鞋啊...
#
# 涼鞋就算材質防水也沒意義啊涼鞋本來就是會讓腳濕的ＸＤＤ
#
# 然後有點陷入憂鬱，覺得自己真的很奢侈，很愛花錢
#
# 明明賺得超少，生活又從來不省，還隨隨便便就一兩千亂噴
#
#
# 雖然我很少買衣服，鞋子以女生來說絕對算少的，一直安慰自己就算多買一雙涼鞋也沒差
#
# 但還是很憂鬱，覺得自己憑什麼穿一雙一千五的涼鞋啊
#
#
# 因為我錢都幾乎花在吃的上面，我從來不省吃的，想吃就吃想喝就喝，
#
# 覺得人生都這麼痛苦連吃都不能快快樂樂的還有什麼生活意義，
#
# 所以每天至少都會花三四百塊買吃喝的，我不敢記帳哈哈哈哈
#
#
# 三百大概就是正餐+零食（我很愛吃曼陀珠）+飲料（無糖綠
#
# 基本上沒有吃很多，國中時我可能比較擔心胖，但現在比較擔心錢...
#
# 尤其台北動不動跟朋友/同事吃好一點的餐廳又都是兩百起跳
#
#
#
# 我都會安慰自己說，啊反正自己不太買化妝品貴重物衣服啊。
#
# 每個人都有執著的點，像我姐就很喜歡買衣服包包，但他都是買便宜的只是喜新厭舊而已
#
# 昨天他才為了衣服還什麼的多花390而在意一個晚上
#
# 「人生最煩的就是你今天買的東西明天就特價了，差390差超多的欸！」
#
# 他就問我：難道你不覺得390很多嗎？
#
# 我說：以你買的東西來說的確算很多，但因為390而難過一整個晚上也是有點不值得啦...
#
# 更重要的是，我可能心底隱隱覺得，啊反正390我一天就可以吃掉了XDDD（幹
#
#
# 其實我只是想說，他在意衣服我在意食物，
#
# 結果我今天花了一千五買一雙涼鞋...
#
#
# 其實我就只是不願意省吃儉用的討債鬼吧，好煩。
#
# 我可以為了一千五囉唆這麼長一篇也是蠻不容易的...
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 219.71.210.74
# ※ 文章網址: https://www.ptt.cc/bbs/prozac/M.1481383439.A.A87.html
# ※ 編輯: lyviasun (219.71.210.74), 12/10/2016 23:24:48
# 推 knai: 最後一句 我笑了XDDDDD 12/10 23:53
# 推 qqqlisa: 最後一句XD  不過我也是覺得人生這麼痛苦當然要享受美食 12/11 00:05
# → hesione: XDDD 不過我覺得不會濕的涼鞋比會濕的好穿耶 雖然一樣是 12/11 02:47
# → hesione: 濕 用水沖腳並不討厭 討厭的是濕濕的材質黏著啊 12/11 02:48
# 推 Belieeve: 好的鞋子可以穿久一點，而且鞋子讓腳舒服很重要啊XD 12/11 07:19
# 推 lukeloo: 喪失工作能力以後，都不太敢花錢了！很怕有一天會沒錢吃 12/11 09:06
# → lukeloo: 飯!但一天200元吃飯的話，大概這輩子的吃飯錢都有了，可 12/11 09:06
# → lukeloo: 是就是會擔心呢!-_- 12/11 09:06
# 推 averyavery: 有天拿出來穿覺得很好看 就會想:還好有買 12/11 09:37
# 推 colza: 最後一句道盡人生。人生太多時候都是如此了，大吼完就笑吧 12/13 07:14
#
# 作者llltwilight (llltwilight)看板prozac標題[陰天] 時間時間Sat Dec 10 23:36:22 2016
# 羨慕可以活在當下的人
# 如數家珍地細數生活
#
# 我每天醒來只感到痛苦
# 為什麼
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 123.192.69.244
# ※ 文章網址: https://www.ptt.cc/bbs/prozac/M.1481384185.A.D31.html
# 推 lyviasun: 上次我主管跟我說「你連這種事情都做不好不就表示你12/10 23:37
# → lyviasun: 生活一團糟」我都忍住不敢回嘴「我真的生活一團糟」12/10 23:38
# 我不知道什麼算生活
# ※ 編輯: llltwilight (123.192.69.244), 12/11/2016 00:12:53
# 推 qqqlisa: 每天醒來不是賺錢就是花錢 12/11 00:16
#
# 作者wanchieh (披著狼皮的羊)看板prozac標題[陰天] 躁鬱症之是否該讓他自由時間Sun Dec 11 00:59:36 2016
# 我知道他很愛我。
#
# 他不只一次跟他的好友抱怨，我的揮霍、我的花錢如流水，他告訴別人我的金錢觀念不好
# ，用錢用的很誇張。
#
# 他不知道，他們也不知道，我很難受。
#
# 他不只一次跟他的好友傾訴，我的情緒、我的各種歇斯底里，他告訴別人我的悲觀厭世，
# 還有我種種發神經的行為。
#
# 還是跟一個他自認不算好的女生朋友說.....
#
# 他不知道，他們也不知道，我很痛苦。
#
# 我知道他也需要跟別人談心，我知道他也想和朋友討論自己該怎麼做。
#
# 但除了醫生，到底有誰理解我生病了.....
#
# 我已經崩潰了，這陣子儘管我都有乖乖遵照醫囑，但我還是崩潰了。
#
# 我好痛苦。
#
# 我知道該讓他離開，但我卻又想厚臉皮的賴著他。
#
# 我真的不知道該怎麼辦了.....
#
# 好痛，真的好痛。
#
#
#
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 111.82.153.180
# ※ 文章網址: https://www.ptt.cc/bbs/prozac/M.1481389178.A.7BC.html
#
# 作者grimmm51764 (四葉)看板prozac標題[問題] 台北的同志友善醫師時間Sun Dec 11 01:49:59 2016
# 敝人目前是看昆明醫院的衛醫師
# 雖然覺得他人不錯
#
# 可是多關注在藥物的使用情況上
#
# 而且感覺頗忙 不太會去關注病人心理層面
#
# 每次去看沒幾分鐘就趕領藥了
#
# 之前是看台南親戚推薦的簡崇暐醫師
#
# 覺得他人真的很好 除了用藥情況外也會和我聊個十幾二十分
# 而且他很帥(斯文眼鏡有點像阿咪老師 聲音略帶磁性)
# 每次回台南要看他心情都會很好
# 他也很願意傾聽我身為同志的壓力和目前遇到的困境 但後來鑒於通車費昂貴 被父母逼著在台北看......
# 不曉得台北有沒有Gay friendly 和願意聊比較久的醫師呢...？男女不拘
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 61.231.238.29
# ※ 文章網址: https://www.ptt.cc/bbs/prozac/M.1481392202.A.84D.html
# → flowergone: 呃 大部分醫院醫師都沒有什麼時間多聊 12/11 12:49
# 推 ej01019: 推簡醫師 12/11 13:01
# 推 EM2A: 要多聊的話建議還是找諮商師哦～ 12/11 13:23
# 推 Belieeve: PSY板有人問過同志友善諮商師哦 ：] 12/11 17:59
# → Belieeve: 也可以打LGBT諮詢熱線詢問 12/11 17:59
# 推 yk6mp6: 台北馬偕林穎不錯喔 12/11 19:04
# 推 yk6mp6: 雖然他很忙但願意聊，不過可能也是因為這樣要掛到他的號 12/11 19:06
# → yk6mp6: 不容易QQ 12/11 19:06
# → grimmm51764: 我也有向衛醫師問諮商的部分 他是說明年昆明可能會 12/11 19:53
# → grimmm51764: 有 但4～500元對目前身為全職考生的我也是一筆不小 12/11 19:53
# → grimmm51764: 的花費(參考書和題庫書都要省吃儉用買QQ) 還是會奢 12/11 19:53
# → grimmm51764: 望有能聊比較久的醫師xD 12/11 19:53
# → grimmm51764: 謝謝樓上推薦的林穎 但不好掛就...QQ 12/11 19:55
# 推 aegisiz: 葉佐緯一般門診能聊到十五分鐘左右 12/11 21:26
#
# 作者wwweer267 (Boy)看板prozac標題[陰天] 我恨你又恨我自己時間Sun Dec 11 03:37:51 2016
# 我恨你總是看不見我
#
# 我恨你總是不自覺的傷害我
#
# 我恨你的自私
#
# 我一直記得那句我一直記得
#
# 你不知道你傷的我多深
#
# 你不知道我把自己的內心關的緊緊的不願在打開
#
# 你不知道多少夜裡在棉被裡吶喊哭泣
#
#
# 可是我又好恨我自己
#
# 不能成為你心中的那個人
#
# 像個喪家犬在一旁
#
# 看著 眼眶濕潤 但是努力的不讓眼淚滴下
#
#
# 我到底還有多久能跳出這個漩渦...
# 告訴我...
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 42.79.243.150
# ※ 文章網址: https://www.ptt.cc/bbs/prozac/M.1481398673.A.194.html
# → RIPsomeday: 問世間情是何物，拍拍 12/11 06:08
#
# 作者chanel92 (小香)看板prozac標題[陰天] 時間Sun Dec 11 04:51:08 2016
# 吃了抗焦慮劑一樣失眠
#
# 快把自己搞瘋了
#
# 藥物不是我真正需要的吧
#
# 也許
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 111.82.116.189
# ※ 文章網址: https://www.ptt.cc/bbs/prozac/M.1481403071.A.015.html
#
# 作者flying1618 (六年)看板prozac標題[閒聊] 聖誕交換禮物時間Sun Dec 11 10:08:29 2016
# 哈囉~大家好
#
# 各位還記得前兩年z大舉辦的聖誕交換禮物嗎?
#
# 小妹前兩年都有參加，覺得收到卡片和禮物的感覺很溫馨，
#
# 整個過程也都很令人期待，
#
# 想說今年也延續這個活動，
#
# 希望有人願意參加，讓大家在這個聖誕節不孤單>////<
#
#
# 有意願參加的版友請推文「參加」，超過10人活動才舉辦，最多20人喔！
#
# 寄件方式有：郵寄(包裹or掛號）/7-11寄貨/全家寄貨
#
# 禮物金額100~200元，一定要附上小卡片喔~!!!
#
#
# 希望大家願意參與:)
#
#
# 活動報名至12/15，如果未滿10人活動就取消>"<
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 118.233.168.175
# ※ 文章網址: https://www.ptt.cc/bbs/prozac/M.1481422113.A.994.html
# 推 teapa: 推 12/11 10:11
# 推 alice0730: 推 12/11 10:42
# 推 moteel: 推 12/11 10:46
# 請問以上版友要參加嗎？還是純推呢？
# ※ 編輯: flying1618 (118.233.168.175), 12/11/2016 10:47:22
# 推 moteel: 我要參加^^ 12/11 10:57
# 推 babe18: 參加 12/11 11:18
# 推 lemonish98: 參加！！ 12/11 11:58
# → EM2A: 參加！！！ 12/11 13:25
# 推 csy812: 我想參加~ 12/11 14:45
# 推 piedtw: 純推 12/11 15:03
# 推 Yinsin: 純推+1 12/11 15:21
# 推 lenakaho: 參加 12/11 16:07
# 推 gcfs1597: 參加++ 12/11 16:40
# 推 lydiahsieh: 參加:D 12/11 17:01
# 推 pinpo: 純推，最近寄平信一週才到，要寄平信的注意別變賀年卡囉！ 12/11 17:43
# ※ 編輯: flying1618 (118.233.168.175), 12/11/2016 17:45:19
# 推 Wanda18: 參加！ 12/11 18:22
# 推 kid3875215: 參加 12/11 18:23
# 推 jk529300: 參加 12/11 19:50
# 推 wrenching08: 參加!! 12/11 20:41
# 推 alice0730: 要參加 12/11 21:34
# 推 k09090806: 純推 到時人應該在綠島 祝大家順利開心!!! 12/11 21:41
# 推 xing0730: 參加 12/12 01:29
# 推 teapa: 參加 12/12 10:56
# 目前加上我，總共有16人參加>////<
# 還有剩下四個名額，希望大家能夠報名喔！
# ※ 編輯: flying1618 (211.72.182.165), 12/12/2016 19:55:24
# 推 FlyFuta: 先推，很猶豫... 12/13 02:29
# 推 g4zoco196: 純推    之前報名集體聖誕交換賀卡失敗有陰影........ 12/13 15:46
# 推 yinguichen: 參加 12/13 21:20
# 推 honhun: 參加 12/21 22:03
#
# 作者ej01019 (真正)看板prozac標題[閒聊] 媽時間Sun Dec 11 13:12:01 2016
#
# 最近很愛把關係拉近
#
# 但又同時侵犯我的隱私
#
# 這種兩面手法其實在放不開的時候是一種折磨
#
# 不過現在看很開
#
# 反正他們就是那樣也不可能改變
#
# 最近一次和友人吃飯
#
# 他爸還把自己的醫生介紹給他
#
# 很支持他就醫和諮商
#
# 這一次我沒有替代的受傷也沒有羨慕
#
# 反而替他開心O(∩_∩)O
#
#
#
#
# 現在心態很不一樣了
#
# 醫生說他感覺很陌生一時之間不知道要怎麼辦
#
# 心理師說他覺得我這樣子很好
#
# 不再有不切實際的期望
#
# 也就不會受傷害：）
#
# -----
# Sent from JPTT on my Samsung SM-E7000.
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 223.141.241.129
# ※ 文章網址: https://www.ptt.cc/bbs/prozac/M.1481433124.A.237.html
#
# 作者you2012 (無法說的想念)看板prozac標題[問題]時間Sun Dec 11 13:40:22 2016
#
# 我是輕微憂鬱症...目前已停藥約半年。
# 最常有的是焦慮的狀況，
# 但是我是研究生有論文壓力、前陣子狀況好點了也有接其他案子。
# 每天處在忙碌之中，但是昨晚突然崩潰了。
# 面臨案子已經超過期限要晚交成果，
# 每週又要跟老師meeting要準備論文的內容…昨天和今天我卻一直處在焦慮的狀態，
# 沒辦法好好做事…
# 吃了醫生說可以緊急安撫情緒的藥了、
# 也找一些事情讓自己轉移注意力，
# 可是事情做完了又會回到壓力和焦慮裡，
# 而且因為可工作的時間又更少，
# 就又更焦慮…如此的惡性循環……
#
# 請問我該怎麼做，
# 可以讓自己脫離焦躁的狀態好好做事情呢………真的好困擾...
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 218.161.48.97
# ※ 文章網址: https://www.ptt.cc/bbs/prozac/M.1481434826.A.92E.html
# ※ 編輯: you2012 (218.161.48.97), 12/11/2016 13:41:45
#
# 作者ej01019 (真正)看板prozac標題[閒聊] 被討厭的勇氣要改編成刑事劇時間Sun Dec 11 13:56:47 2016
#
# 《被討厭的勇氣》改編刑事劇　將由香里奈主演
#
# 日本知名女星香里奈（翻攝自youtube）
#
# 據日本媒體報導，知名女星香里奈將主演明年1月在富士電視台播出的電視劇《被討厭的勇氣》，本劇是以暢銷心理書籍《被討厭的勇氣》為基礎重新改編的刑事劇，這是2012年日本電視台《Dirty Mama!》以來，睽違五年香理奈再度扮演警察，同劇卡司還有傑尼斯偶像團體「NEWS」成員加藤成亮、知名演員椎名桔平。
#
#
# 《被討厭的勇氣》一書以奧地利心理學家阿德勒的學說為基礎，透過青年與哲學家對話的形式，鼓勵讀者勇敢做自己。阿德勒與榮格、佛洛伊德齊名，被稱作「心理學三巨頭」。《被討厭的勇氣》在台灣相當暢銷，長期佔據各大書籍銷售排行榜，也使得與阿德勒相關的出版品大為流行。
#
#
# 本劇主角女警庵堂蘭子（香理奈飾）可說是「阿德勒心裡學」的代言人，她是警視廳刑事部捜査一課8係的王牌，極為自我中心，聽不進他人意見，也毫不在意外人對她的評價，常因為辦案方式而與組織起衝突。相反的，她的搭檔青山年雄（加藤成亮飾）卻是個很在意別人看法、優柔寡斷的人，年雄起初非常討厭蘭子，在習得「阿德勒心理學」後才漸漸對她改觀。
#
#
# 另一個主要角色是帝都大學文學院心理系教授大文字哲人（椎名桔平飾），專攻犯罪心理學的他經常協助警視廳辦案，年雄的「阿德勒心理學」也是他教的。對於完全無法理解蘭子想法的年雄而言，大文字哲人是無所不知的存在。
#
#
# 《被討厭的勇氣》將採取一集一案件的模式，編劇為《HOPE ～期待值零的新進員工～》德永友一，預計自2017年1月開始，日本時間每週四晚間十點在富士電視台播出。
#
# -----
# Sent from JPTT on my Samsung SM-E7000.
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 223.141.241.129
# ※ 文章網址: https://www.ptt.cc/bbs/prozac/M.1481435809.A.174.html
#
# 作者lemonish98 (草萱)看板prozac標題[陰天] 憤怒及無力感時間Sun Dec 11 17:06:48 2016
# 吃藥的第3週。
#
# 或許是藥效發揮了，
# 這週憂鬱的感覺少了一些，但取而代之的是無力及憤怒。
#
# 我討厭這樣。
#
# 前幾天才寫下在死前想溫柔對待所有人（除了討厭的那些）
# 如果無法控制的情緒必定要化為實體行動
# 那麼比起傷害別人我更寧願傷害自己。
#
# 並不是因為我很善良，
# 相反地，我既自私又任性。
# 為了保護自己腦內僅存的美好幻想和避免朋友受傷，
# 以及享受自殘帶來的病態快感，
# 才會裝出一副善良的樣子。
#
# 我確實很討人厭，
# 只是我幾乎不會把腦中那些糟糕的言論說出來
# 我是那麼地喜歡把文字組成句子，
# 溫暖的、憂傷的句子，
# 所以我不願意把那些字拼湊成傷人的句子脫口而出，
#
# 我努力不變成自己討厭的人。
#
#
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 1.161.171.242
# ※ 文章網址: https://www.ptt.cc/bbs/prozac/M.1481447210.A.75F.html
# 推 knai: 你很溫柔 應該很多事都往自己心裡塞 憤怒無力 有種既視感 12/11 17:13
# → lemonish98: 謝謝k大QQ被說溫柔感覺心頭一陣暖 12/12 22:22

# %%
import requests
from bs4 import BeautifulSoup
import xlsxwriter

workbook = xlsxwriter.Workbook('test3.xlsx')#create a file 
worksheet = workbook.add_worksheet()#create a sheet

a = 1661
b = 1662
n = []
def get_title():
    for i in range(a,b):
        res = requests.get("https://www.ptt.cc/bbs/prozac/index"+str(i)+".html")
        soup = BeautifulSoup(res.text)
        for website in soup.select(".r-ent"):
            try:    
                res2 = requests.get('https://www.ptt.cc/'+website("a")[0]['href'])
                soup2 = BeautifulSoup(res2.text)
                if "資訊" in (soup2.select(".article-meta-value")[2].text):
                    pass
                else:
                    soup3 = soup2.select(".bbs-screen.bbs-content")[0].text
                    content =soup3.split("※") and soup3.split("--")
                    content2 = content[0].split("2016")
#                     worksheet.write(row,0,content2[1])
                    n.append(content2[1])
            except:
                pass
    row=0
    for each_content in n:
        worksheet.write(row, 0, each_content)
        row = row+1
get_title()
workbook.close()
# Out:
# C:\Users\弘林\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file C:\Users\弘林\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
import requests
from bs4 import BeautifulSoup
import xlsxwriter

workbook = xlsxwriter.Workbook('test.xlsx')#create a file 
worksheet = workbook.add_worksheet()#create a sheet

a = 1661
b = 1662
j = []
k = []
l = []
m = []
def get_title():
    for i in range(a,b):
        res = requests.get("https://www.ptt.cc/bbs/prozac/index"+str(i)+".html")
        soup = BeautifulSoup(res.text)
        for website in soup.select(".r-ent"):
            try:    
                res2 = requests.get('https://www.ptt.cc/'+website("a")[0]['href'])
                soup2 = BeautifulSoup(res2.text)
                if "資訊" in (soup2.select(".article-meta-value")[2].text):
                    pass
                else:
#                     print("--------------------------------------------------------------------------------------------------")
#                     推，箭頭，噓
                    for i in range(len(soup2.select(".push"))):
                        j.append(soup2.select(".push-tag")[i].text)
#                     推文者ID
                    for i in range(len(soup2.select(".push"))):
                        k.append(soup2.select(".push-userid")[i].text)
#                     推文內容
                    for i in range(len(soup2.select(".push"))):
                        l.append(soup2.select(".push-content")[i].text)
#                     推文時間
                    for i in range(len(soup2.select(".push"))):
                        m.append(soup2.select(".push-ipdatetime")[i].text)
            except:
                pass
    row=0
    for each_reply_cagetory in j:
        worksheet.write(row, 0, each_reply_cagetory)
        row = row+1
    row=0
    for each_reply_ID in k:
        worksheet.write(row, 1, each_reply_ID)
        row = row+1
    row=0
    for each_reply_content in l:
        worksheet.write(row, 2, each_reply_content)
        row = row+1
    row=0
    for each_reply_time in m:
        worksheet.write(row, 3, each_reply_time)
        row = row+1
get_title()
workbook.close()
# Out:
# C:\Users\弘林\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file C:\Users\弘林\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
import requests
from bs4 import BeautifulSoup
import xlsxwriter
import jieba

workbook = xlsxwriter.Workbook('text2.xlsx')#create a file 
worksheet = workbook.add_worksheet()#create a sheet

jieba.set_dictionary('dict.txt.big.txt')

a = 1608
b = 1611
e = []
f = []
g = []
h = []
n = []
m = []
def get_title():
    for i in range(a,b):
        res = requests.get("https://www.ptt.cc/bbs/prozac/index"+str(i)+".html")
        soup = BeautifulSoup(res.text)
        for website in soup.select(".r-ent"):
            try:    
                res2 = requests.get('https://www.ptt.cc/'+website("a")[0]['href'])
                soup2 = BeautifulSoup(res2.text)
                if "資訊" in (soup2.select(".article-meta-value")[2].text):
                    pass
                else:
                    c = soup2.select(".article-meta-value")[2].text
                    d = c.split("]")
#                     標題分類
                    e.append(d[0]+"]")
#                     標題內容
                    f.append(d[1])
# 作者
                if "資訊" in (soup2.select(".article-meta-value")[2].text):
                    pass
                else:
                    g.append(soup2.select(".article-meta-value")[0].text)
# 時間
                if "資訊" in (soup2.select(".article-meta-value")[2].text):
                    pass
                else:
                    h.append(soup2.select(".article-meta-value")[3].text)
                if "資訊" in (soup2.select(".article-meta-value")[2].text):
                    pass
                else:
                    soup3 = soup2.select(".bbs-screen.bbs-content")[0].text
                    content =soup3.split("※") and soup3.split("--")
                    content2 = content[0].split("2016")
                    n.append(content2[1])
                if "資訊" in (soup2.select(".article-meta-value")[2].text):
                    pass
                else:
                    soup3 = soup2.select(".bbs-screen.bbs-content")[0].text
                    content =soup3.split("※") and soup3.split("--")
                    content2 = content[0].split("2016")
                    jeba1=('/'.join(jieba.cut(content2[1],cut_all=False)))
                    m.append(jeba1)
            except:
                pass
    row=0
    for each_cagetory in e:
        worksheet.write(row, 0,each_cagetory)
        row = row+1
    row=0
    for each_title in f:
        worksheet.write(row, 1, each_title)
        row = row+1
    row=0
    for each_author in g:
        worksheet.write(row, 2, each_author)
        row = row+1
    row=0
    for each_time in h:
        worksheet.write(row, 3, each_time)
        row = row+1
    row=0
    for each_content in n:
        worksheet.write(row, 4, each_content)
        row = row+1
    row=0
    for each_jieba in m:
        worksheet.write(row, 5, each_jieba)
        row = row+1
get_title()
workbook.close()
# Out:
# C:\Users\弘林\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file C:\Users\弘林\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# Building prefix dict from C:\Users\弘林\Documents\proj-prozac專案\dict.txt.big.txt ...
# Loading model from cache C:\Users\弘林\AppData\Local\Temp\jieba.ud3be88558d1ae3c49c32a7e71cdb2d43.cache
# Loading model cost 122.529 seconds.
# Prefix dict has been built succesfully.

# %%
import requests
from bs4 import BeautifulSoup
import xlsxwriter

workbook = xlsxwriter.Workbook('test4.xlsx')#create a file 
worksheet = workbook.add_worksheet()#create a sheet

a = 1661
b = 1662
e = []
f = []
j = []
k = []
l = []
m = []

def get_title():
    row=0
    row1=0
    for i in range(a,b):
        res = requests.get("https://www.ptt.cc/bbs/prozac/index"+str(i)+".html")
        soup = BeautifulSoup(res.text)
        for website in soup.select(".r-ent"):
            try:    
                res2 = requests.get('https://www.ptt.cc/'+website("a")[0]['href'])
                soup2 = BeautifulSoup(res2.text)
                if "資訊" in (soup2.select(".article-meta-value")[2].text):
                    pass
                else:
                    c = soup2.select(".article-meta-value")[2].text
                    d = c.split("]")
#                     標題分類
                    e.append(d[0]+"]")
#                     標題內容
                    f.append(d[1])
                if "資訊" in (soup2.select(".article-meta-value")[2].text):
                    pass
                else:
#                     print("--------------------------------------------------------------------------------------------------")
#                     推，箭頭，噓
                    
                    worksheet.write(row1,0,c)
                    for i in range(len(soup2.select(".push"))):
                        j=soup2.select(".push-tag")[i].text
                        k=soup2.select(".push-userid")[i].text
                        l=soup2.select(".push-content")[i].text
                        m=soup2.select(".push-ipdatetime")[i].text
                        worksheet.write(row, 1, j)
#                    
                        worksheet.write(row, 2, k)
#                     
                        worksheet.write(row, 3, l)
#                     
                        worksheet.write(row, 4, m)
                        row=row+1
                    row1=row1+row
            except:
                pass
#     row=0
#     for each_title in f:
#         worksheet.write(row, 1, each_title)
#     row=0
#     for each_reply_cagetory in j:
#         worksheet.write(row, 0, each_reply_cagetory)
#         row = row+1
#     row=0
#     for each_reply_ID in k:
#         worksheet.write(row, 1, each_reply_ID)
#         row = row+1
#     row=0
#     for each_reply_content in l:
#         worksheet.write(row, 2, each_reply_content)
#         row = row+1
#     row=0
#     for each_reply_time in m:
#         worksheet.write(row, 3, each_reply_time)
#         row = row+1
get_title()
workbook.close()
# Out:
# C:\Users\弘林\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file C:\Users\弘林\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
